# %% [markdown]
# <a href="https://colab.research.google.com/github/plaban1981/NLP/blob/master/Mohit_Iyer_NLP_Class_2022_(Advanced_NLP)_1_Introduction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## UMass CS685 S22 (Advanced NLP) #1: Introduction

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# * Why Self Supervised - we do not need to collect labels for this task.
#
# * In language modeling the labels come from the text by splitting it

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# * Create low dimensional representation of the text to be used as a part of the downstream tasks

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
